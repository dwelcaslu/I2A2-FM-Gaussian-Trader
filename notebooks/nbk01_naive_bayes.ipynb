# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
X_train
# Out:
# array([[4.6, 3.1, 1.5, 0.2],
#        [5.9, 3. , 5.1, 1.8],
#        [5.1, 2.5, 3. , 1.1],
#        [4.6, 3.4, 1.4, 0.3],
#        [6.2, 2.2, 4.5, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [4.8, 3. , 1.4, 0.1],
#        [7.1, 3. , 5.9, 2.1],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.5, 3. , 5.8, 2.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.7, 3.3, 5.7, 2.1],
#        [4.5, 2.3, 1.3, 0.3],
#        [6.2, 3.4, 5.4, 2.3],
#        [4.9, 3. , 1.4, 0.2],
#        [5.7, 2.5, 5. , 2. ],
#        [6.9, 3.1, 5.4, 2.1],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [7.2, 3. , 5.8, 1.6],
#        [5.1, 3.5, 1.4, 0.3],
#        [4.4, 3. , 1.3, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.5, 2.3, 4. , 1.3],
#        [6.8, 3.2, 5.9, 2.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [5. , 3.2, 1.2, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.4, 3.4, 1.5, 0.4],
#        [7.7, 2.6, 6.9, 2.3],
#        [4.9, 2.4, 3.3, 1. ],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [6. , 3. , 4.8, 1.8],
#        [5.8, 4. , 1.2, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.1, 3.8, 1.5, 0.3],
#        [4.7, 3.2, 1.6, 0.2],
#        [7.4, 2.8, 6.1, 1.9],
#        [5. , 3.3, 1.4, 0.2],
#        [6.3, 3.4, 5.6, 2.4],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.7, 2.6, 3.5, 1. ],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.7, 3. , 5. , 1.7],
#        [5. , 3. , 1.6, 0.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.1, 3.4, 1.5, 0.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [5.8, 2.7, 4.1, 1. ],
#        [7.7, 3.8, 6.7, 2.2],
#        [4.6, 3.2, 1.4, 0.2]])

# %%
y_train
# Out:
# array([0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 0,
#        0, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1, 0,
#        2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 1, 0, 1, 2, 2, 0, 1, 1,
#        1, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.predict(X_train)
# Out:
# array([0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 0,
#        0, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1, 0,
#        2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 2, 0, 1, 2, 2, 0, 1, 1,
#        2, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
gnb.predict_proba(X_train)
# Out:
# array([[1.00000000e+000, 3.14523897e-015, 3.16878307e-033],
#        [5.94230825e-241, 1.15865992e-001, 8.84134008e-001],
#        [5.71733573e-050, 1.00000000e+000, 7.56829143e-011],
#        [1.00000000e+000, 1.38948292e-015, 2.32059947e-032],
#        [4.53811517e-169, 9.99795311e-001, 2.04688707e-004],
#        [0.00000000e+000, 1.47974598e-012, 1.00000000e+000],
#        [7.25867747e-131, 9.99994573e-001, 5.42717052e-006],
#        [1.00000000e+000, 6.94088831e-016, 7.33903833e-035],
#        [0.00000000e+000, 1.88224228e-007, 9.99999812e-001],
#        [0.00000000e+000, 1.52765707e-008, 9.99999985e-001],
#        [0.00000000e+000, 4.38584077e-007, 9.99999561e-001],
#        [5.92878775e-323, 2.62142567e-005, 9.99973786e-001],
#        [1.00000000e+000, 2.33515399e-016, 2.00954886e-032],
#        [1.00000000e+000, 2.80368045e-015, 1.88365220e-032],
#        [1.14903147e-261, 3.52669861e-004, 9.99647330e-001],
#        [0.00000000e+000, 6.13373355e-007, 9.99999387e-001],
#        [1.00000000e+000, 3.26163896e-013, 4.45264150e-032],
#        [1.52681107e-319, 2.65556462e-007, 9.99999734e-001],
#        [1.00000000e+000, 4.21385526e-015, 2.39617311e-033],
#        [4.69762644e-248, 6.72190858e-002, 9.32780914e-001],
#        [1.14066327e-304, 4.94816059e-006, 9.99995052e-001],
#        [1.00000000e+000, 2.64516877e-016, 2.25907372e-034],
#        [1.00000000e+000, 6.46461758e-017, 8.39073582e-034],
#        [5.11558453e-309, 1.40663966e-003, 9.98593360e-001],
#        [1.00000000e+000, 2.75276529e-015, 1.13303452e-031],
#        [1.00000000e+000, 1.00265554e-015, 3.39303520e-034],
#        [1.00000000e+000, 1.43371091e-012, 1.17832165e-026],
#        [3.28597522e-117, 9.99999825e-001, 1.74621074e-007],
#        [0.00000000e+000, 6.30303396e-009, 9.99999994e-001],
#        [0.00000000e+000, 2.73645799e-010, 1.00000000e+000],
#        [1.00000000e+000, 2.33800057e-016, 1.90938939e-033],
#        [1.00000000e+000, 6.53101519e-015, 7.85564027e-033],
#        [1.00000000e+000, 8.56587426e-016, 4.56014899e-033],
#        [3.13704734e-154, 9.99983479e-001, 1.65209801e-005],
#        [1.44681632e-155, 9.98866873e-001, 1.13312750e-003],
#        [1.00000000e+000, 1.02562372e-015, 9.04085006e-034],
#        [9.99999995e-001, 4.91487102e-009, 4.54764890e-024],
#        [2.37169628e-141, 9.99954654e-001, 4.53462948e-005],
#        [1.00000000e+000, 2.82546573e-012, 6.75049210e-028],
#        [0.00000000e+000, 3.27704140e-012, 1.00000000e+000],
#        [1.63190902e-059, 1.00000000e+000, 3.01530163e-011],
#        [0.00000000e+000, 2.17909083e-011, 1.00000000e+000],
#        [7.18058817e-156, 9.97571780e-001, 2.42821950e-003],
#        [1.00000000e+000, 6.87556265e-019, 6.87093533e-035],
#        [2.94059567e-213, 3.54391892e-001, 6.45608108e-001],
#        [1.00000000e+000, 1.17218921e-016, 3.24700965e-032],
#        [0.00000000e+000, 1.19152776e-009, 9.99999999e-001],
#        [1.00000000e+000, 5.24513110e-016, 1.67759307e-031],
#        [1.00000000e+000, 9.96961503e-015, 2.29029076e-032],
#        [0.00000000e+000, 1.26648483e-006, 9.99998734e-001],
#        [1.00000000e+000, 7.64560329e-016, 1.96290277e-033],
#        [0.00000000e+000, 1.06896840e-008, 9.99999989e-001],
#        [6.74558178e-124, 9.99997794e-001, 2.20618311e-006],
#        [1.50029105e-105, 9.99999872e-001, 1.27767370e-007],
#        [8.54303969e-072, 1.00000000e+000, 4.03861793e-010],
#        [1.59175654e-310, 7.68847004e-007, 9.99999231e-001],
#        [1.46100831e-302, 1.40467787e-006, 9.99998595e-001],
#        [1.88414741e-203, 9.94592929e-001, 5.40707118e-003],
#        [4.77360854e-228, 1.33957821e-001, 8.66042179e-001],
#        [1.00000000e+000, 9.33469485e-014, 1.05573302e-031],
#        [3.57901152e-083, 1.00000000e+000, 3.65668438e-010],
#        [0.00000000e+000, 1.47378634e-008, 9.99999985e-001],
#        [3.51610244e-249, 8.78191938e-002, 9.12180806e-001],
#        [1.00000000e+000, 1.57168118e-015, 1.00684378e-032],
#        [2.57767740e-166, 9.99620074e-001, 3.79925592e-004],
#        [4.58832683e-123, 9.99995737e-001, 4.26286076e-006],
#        [1.71156594e-212, 2.13001550e-001, 7.86998450e-001],
#        [1.05720077e-149, 9.99993077e-001, 6.92341777e-006],
#        [1.00000000e+000, 1.33212110e-015, 1.38109987e-032],
#        [1.00000000e+000, 4.22077386e-014, 3.73782686e-029],
#        [1.00000000e+000, 1.45419928e-015, 3.49653377e-034],
#        [1.90890219e-295, 4.26615357e-003, 9.95733846e-001],
#        [5.82039653e-110, 9.99999988e-001, 1.16120615e-008],
#        [0.00000000e+000, 2.23592942e-013, 1.00000000e+000],
#        [1.00000000e+000, 5.35370206e-016, 6.43533484e-034]])

# %%
gnb.class_count_
# Out:
# array([29., 20., 26.])

# %%
gnb.class_prior_
# Out:
# array([0.38666667, 0.26666667, 0.34666667])

# %%
gnb.classes_
# Out:
# array([0, 1, 2])

# %%
gnb.epsilon_
# Out:
# 3.6399040000000003e-09

# %%
gnb.sigma_
# Out:
# array([[0.10321047, 0.13208086, 0.01629013, 0.00846612],
#        [0.256275  , 0.0829    , 0.255275  , 0.046     ],
#        [0.38869823, 0.10147929, 0.31303255, 0.04763314]])

# %%
gnb.theta_
# Out:
# array([[4.97586207, 3.35862069, 1.44827586, 0.23448276],
#        [5.935     , 2.71      , 4.185     , 1.3       ],
#        [6.77692308, 3.09230769, 5.73461538, 2.10769231]])

# %%
y_pred = gnb.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 75 points : 4
